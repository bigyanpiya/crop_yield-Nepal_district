# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataframe_yield = pd.read_csv("C:/Users/ASUS/crop/project/yield.csv") #laoding yield data

# %% [markdown]
# # EDA of yield data

# %%
dataframe_yield
# Out:
#      Domain Code                        Domain  Area Code (M49)   Area  \
# 0            QCL  Crops and livestock products              524  Nepal
# 1            QCL  Crops and livestock products              524  Nepal
# 2            QCL  Crops and livestock products              524  Nepal
# 3            QCL  Crops and livestock products              524  Nepal
# 4            QCL  Crops and livestock products              524  Nepal
# ...          ...                           ...              ...    ...
# 1641         QCL  Crops and livestock products              524  Nepal
# 1642         QCL  Crops and livestock products              524  Nepal
# 1643         QCL  Crops and livestock products              524  Nepal
# 1644         QCL  Crops and livestock products              524  Nepal
# 1645         QCL  Crops and livestock products              524  Nepal
#
#       Element Code Element  Item Code (CPC)               Item  Year Code  \
# 0             5419   Yield           1371.0  Almonds, in shell       1998
# 1             5419   Yield           1371.0  Almonds, in shell       1999
# 2             5419   Yield           1371.0  Almonds, in shell       2000
# 3             5419   Yield           1371.0  Almonds, in shell       2001
# 4             5419   Yield           1371.0  Almonds, in shell       2002
# ...            ...     ...              ...                ...        ...
# 1641          5419   Yield            111.0              Wheat       2018
# 1642          5419   Yield            111.0              Wheat       2019
# 1643          5419   Yield            111.0              Wheat       2020
# 1644          5419   Yield            111.0              Wheat       2021
# 1645          5419   Yield            111.0              Wheat       2022
#
#       Year      Unit  Value
# 0     1998  100 g/ha  10000
# 1     1999  100 g/ha  10000
# 2     2000  100 g/ha  10000
# 3     2001  100 g/ha  10000
# 4     2002  100 g/ha  10000
# ...    ...       ...    ...
# 1641  2018  100 g/ha  27573
# 1642  2019  100 g/ha  28490
# 1643  2020  100 g/ha  30887
# 1644  2021  100 g/ha  29917
# 1645  2022  100 g/ha  29911
#
# [1646 rows x 12 columns]

# %%
dataframe_yield.tail()
# Out:
#      Domain Code                        Domain  Area Code (M49)   Area  \
# 1641         QCL  Crops and livestock products              524  Nepal
# 1642         QCL  Crops and livestock products              524  Nepal
# 1643         QCL  Crops and livestock products              524  Nepal
# 1644         QCL  Crops and livestock products              524  Nepal
# 1645         QCL  Crops and livestock products              524  Nepal
#
#       Element Code Element  Item Code (CPC)   Item  Year Code  Year      Unit  \
# 1641          5419   Yield            111.0  Wheat       2018  2018  100 g/ha
# 1642          5419   Yield            111.0  Wheat       2019  2019  100 g/ha
# 1643          5419   Yield            111.0  Wheat       2020  2020  100 g/ha
# 1644          5419   Yield            111.0  Wheat       2021  2021  100 g/ha
# 1645          5419   Yield            111.0  Wheat       2022  2022  100 g/ha
#
#       Value
# 1641  27573
# 1642  28490
# 1643  30887
# 1644  29917
# 1645  29911

# %%
dataframe_yield.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1646 entries, 0 to 1645
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Domain Code      1646 non-null   object
#  1   Domain           1646 non-null   object
#  2   Area Code (M49)  1646 non-null   int64
#  3   Area             1646 non-null   object
#  4   Element Code     1646 non-null   int64
#  5   Element          1646 non-null   object
#  6   Item Code (CPC)  1646 non-null   float64
#  7   Item             1646 non-null   object
#  8   Year Code        1646 non-null   int64
#  9   Year             1646 non-null   int64
#  10  Unit             1646 non-null   object
#  11  Value            1646 non-null   int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 154.4+ KB

# %%
# Renaming the column.  
dataframe_yield.rename( columns={"Value": "hg/ha_yield"}, inplace=True)  
dataframe_yield.head()
# Out:
#   Domain Code                        Domain  Area Code (M49)   Area  \
# 0         QCL  Crops and livestock products              524  Nepal
# 1         QCL  Crops and livestock products              524  Nepal
# 2         QCL  Crops and livestock products              524  Nepal
# 3         QCL  Crops and livestock products              524  Nepal
# 4         QCL  Crops and livestock products              524  Nepal
#
#    Element Code Element  Item Code (CPC)               Item  Year Code  Year  \
# 0          5419   Yield           1371.0  Almonds, in shell       1998  1998
# 1          5419   Yield           1371.0  Almonds, in shell       1999  1999
# 2          5419   Yield           1371.0  Almonds, in shell       2000  2000
# 3          5419   Yield           1371.0  Almonds, in shell       2001  2001
# 4          5419   Yield           1371.0  Almonds, in shell       2002  2002
#
#        Unit  hg/ha_yield
# 0  100 g/ha        10000
# 1  100 g/ha        10000
# 2  100 g/ha        10000
# 3  100 g/ha        10000
# 4  100 g/ha        10000

# %% [markdown]
# (hectogram per hectare (Hg/Ha))

# %%
# dropping the unwanted columns.  
dataframe_yield = dataframe_yield.drop(['Year Code','Element Code', 'Element','Area Code (M49)','Domain Code', 'Domain','Unit','Item Code (CPC)'], axis=1)

# %%
dataframe_yield.tail()
# Out:
#        Area   Item  Year  hg/ha_yield
# 1641  Nepal  Wheat  2018        27573
# 1642  Nepal  Wheat  2019        28490
# 1643  Nepal  Wheat  2020        30887
# 1644  Nepal  Wheat  2021        29917
# 1645  Nepal  Wheat  2022        29911

# %%
# Group by Item to find the total yield for each food item
total_yield_per_item = dataframe_yield.groupby('Item')['hg/ha_yield'].sum().sort_values(ascending=False)

print(total_yield_per_item)
# Out:
# Item
# Sugar cane                                                                   13502359
# Cabbages                                                                      5863379
# Bananas                                                                       5329481
# Pineapples                                                                    5255483
# Papayas                                                                       5207364
# Oranges                                                                       4278804
# Pears                                                                         4055671
# Potatoes                                                                      3952366
# Other vegetables, fresh n.e.c.                                                3775378
# Ginger, raw                                                                   3654703
# Other fruits, n.e.c.                                                          3345728
# Apples                                                                        3050632
# Tangerines, mandarins, clementines                                            2921990
# Mangoes, guavas and mangosteens                                               2764828
# Plums and sloes                                                               2646707
# Other citrus fruit, n.e.c.                                                    2594958
# Lemons and limes                                                              2579309
# Peaches and nectarines                                                        2560711
# Persimmons                                                                    2464920
# Cauliflowers and broccoli                                                     2433575
# Other stimulant, spice and aromatic crops, n.e.c.                             2366677
# Apricots                                                                      2224953
# Edible roots and tubers with high starch or inulin content, n.e.c., fresh     1669405
# Green garlic                                                                  1634605
# Walnuts, in shell                                                             1336473
# Chillies and peppers, green (Capsicum spp. and Pimenta spp.)                  1329777
# Lettuce and chicory                                                           1204394
# Tea leaves                                                                    1175249
# Coconuts, in shell                                                            1069010
# Rice                                                                           961654
# Areca nuts                                                                     781772
# Chillies and peppers, dry (Capsicum spp., Pimenta spp.), raw                   744435
# Maize (corn)                                                                   700715
# Wheat                                                                          685759
# Jute, raw or retted                                                            450689
# Other beans, green                                                             378652
# Millet                                                                         370361
# Barley                                                                         364113
# Unmanufactured tobacco                                                         341080
# Soya beans                                                                     306900
# Lentils, dry                                                                   298379
# Pigeon peas, dry                                                               286370
# Chick peas, dry                                                                283112
# Seed cotton, unginned                                                          271999
# Other pulses n.e.c.                                                            270639
# Mustard seed                                                                   257961
# Beans, dry                                                                     246595
# Broad beans and horse beans, dry                                               211518
# Linseed                                                                        194143
# Almonds, in shell                                                              192831
# Buckwheat                                                                      188869
# Nutmeg, mace, cardamoms, raw                                                   155196
# Other oil seeds, n.e.c.                                                        116388
# Coffee, green                                                                   56403
# Name: hg/ha_yield, dtype: int64

# %%
# Group by Year to find the total yield for each year
total_yield_per_year = dataframe_yield.groupby('Year')['hg/ha_yield'].sum().sort_values(ascending=False)

print(total_yield_per_year)
# Out:
# Year
# 2022    3994076
# 2021    3903349
# 2020    3887957
# 2019    3845133
# 2018    3748931
# 2016    3654007
# 2017    3523281
# 2015    3504563
# 2013    3486785
# 2012    3482479
# 2014    3440407
# 1995    3426241
# 2010    3370067
# 2011    3362690
# 1994    3320902
# 2003    3179447
# 2009    3122704
# 2007    3114712
# 2008    3099666
# 2005    3086179
# 2006    3078520
# 2001    3067963
# 2004    3055303
# 2002    3037954
# 1999    3021422
# 2000    2920198
# 1998    2746667
# 1997    2657610
# 1991    2519996
# 1993    2510827
# 1996    2453985
# 1992    2385344
# 1990    2356057
# Name: hg/ha_yield, dtype: int64

# %%
# Plot top yielding food items
plt.figure(figsize=(12, 6))
sns.barplot(x=total_yield_per_item.index, y=total_yield_per_item.values)
plt.xticks(rotation=90)
plt.title('Total Yield per Food Item')
plt.xlabel('Food Item')
plt.ylabel('Total Yield (hg/ha)')
plt.show()

# %%
# Function to get top yielding crops for a particular year
def top_yielding_crops(year, n=10):
    year_data = dataframe_yield[dataframe_yield['Year'] == year]
    top_crops = year_data.groupby('Item')['hg/ha_yield'].sum().sort_values(ascending=False).head(n)
    return top_crops

# Example for the year 2020
print(top_yielding_crops(2019))
# Out:
# Item
# Sugar cane                        496745
# Cabbages                          267637
# Cauliflowers and broccoli         197732
# Bananas                           167854
# Potatoes                          160464
# Other vegetables, fresh n.e.c.    148349
# Coconuts, in shell                142966
# Pineapples                        141142
# Ginger, raw                       134426
# Papayas                           126528
# Name: hg/ha_yield, dtype: int64

# %%
# Example for the year 2020
top_crops_2020 = top_yielding_crops(2020)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_crops_2020.index, y=top_crops_2020.values)
plt.xticks(rotation=90)
plt.title('Top Yielding Crops in 2020')
plt.xlabel('Crop')
plt.ylabel('Total Yield (hg/ha)')
plt.show()

# %%
# Filter the dataset for wheat and maize
df_filtered = dataframe_yield[dataframe_yield['Item'].isin(['Apples', 'Maizea (corn)'])]

# %%
# Group by Year and Item to get the total yield for wheat and maize each year
yield_per_year = df_filtered.groupby(['Year', 'Item'])['hg/ha_yield'].sum().reset_index()

# %%
# Set the style of seaborn
sns.set(style="whitegrid")

# Create a line plot to compare yields
plt.figure(figsize=(14, 8))
sns.lineplot(data=yield_per_year, x='Year', y='hg/ha_yield', hue='Item', marker='o')

# Adding title and labels
plt.title('Comparison of Wheat and Maize Yields Over the Years')
plt.xlabel('Year')
plt.ylabel('Total Yield (hg/ha)')
plt.legend(title='Item')
plt.grid(True)
plt.show()

# %%
# Create a bar plot to compare yields
plt.figure(figsize=(14, 8))
sns.barplot(data=yield_per_year, x='Year', y='hg/ha_yield', hue='Item')

# Adding title and labels
plt.title('Comparison of Wheat and Maize Yields by Year')
plt.xlabel('Year')
plt.ylabel('Total Yield (hg/ha)')
plt.legend(title='Item')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Rainfall Data

# %%
dataframe_rain = pd.read_csv("C:/Users/ASUS/crop/project/rainfall.csv")
dataframe_rain
# Out:
#      Area  Year  rainfall
# 0   Nepal  1990      1500
# 1   Nepal  1991      1500
# 2   Nepal  1992      1500
# 3   Nepal  1993      1500
# 4   Nepal  1994      1500
# 5   Nepal  1995      1500
# 6   Nepal  1996      1500
# 7   Nepal  1997      1500
# 8   Nepal  1998      1500
# 9   Nepal  1999      1500
# 10  Nepal  2000      1500
# 11  Nepal  2001      1500
# 12  Nepal  2002      1500
# 13  Nepal  2003      1500
# 14  Nepal  2004      1500
# 15  Nepal  2005      1500
# 16  Nepal  2006      1500
# 17  Nepal  2007      1500
# 18  Nepal  2008      1500
# 19  Nepal  2009      1500
# 20  Nepal  2010      1500
# 21  Nepal  2011      1500
# 22  Nepal  2012      1500
# 23  Nepal  2013      1500
# 24  Nepal  2014      1500
# 25  Nepal  2015      1500
# 26  Nepal  2016      1500
# 27  Nepal  2017      1500
# 28  Nepal  2018      1500
# 29  Nepal  2019      1500
# 30  Nepal  2020      1500
# 31  Nepal  2021      1500
# 32  Nepal  2022      1500

# %%
dataframe_rain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Area      33 non-null     object
#  1   Year      33 non-null     int64
#  2   rainfall  33 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 924.0+ bytes

# %%
#Merging  
dataframe_main = pd.merge(dataframe_yield, dataframe_rain, on=['Year','Area'])  
filtered_df = dataframe_main[dataframe_main["Year"] == 2020]
filtered_df
# Out:
#        Area                                               Item  Year  \
# 1141  Nepal                                  Almonds, in shell  2020
# 1142  Nepal                                             Apples  2020
# 1143  Nepal                                           Apricots  2020
# 1144  Nepal                                         Areca nuts  2020
# 1145  Nepal                                            Bananas  2020
# 1146  Nepal                                             Barley  2020
# 1147  Nepal                                         Beans, dry  2020
# 1148  Nepal                   Broad beans and horse beans, dry  2020
# 1149  Nepal                                          Buckwheat  2020
# 1150  Nepal                                           Cabbages  2020
# 1151  Nepal                          Cauliflowers and broccoli  2020
# 1152  Nepal                                    Chick peas, dry  2020
# 1153  Nepal  Chillies and peppers, dry (Capsicum spp., Pime...  2020
# 1154  Nepal  Chillies and peppers, green (Capsicum spp. and...  2020
# 1155  Nepal                                 Coconuts, in shell  2020
# 1156  Nepal                                      Coffee, green  2020
# 1157  Nepal  Edible roots and tubers with high starch or in...  2020
# 1158  Nepal                                        Ginger, raw  2020
# 1159  Nepal                                       Green garlic  2020
# 1160  Nepal                                Jute, raw or retted  2020
# 1161  Nepal                                   Lemons and limes  2020
# 1162  Nepal                                       Lentils, dry  2020
# 1163  Nepal                                Lettuce and chicory  2020
# 1164  Nepal                                            Linseed  2020
# 1165  Nepal                                       Maize (corn)  2020
# 1166  Nepal                    Mangoes, guavas and mangosteens  2020
# 1167  Nepal                                             Millet  2020
# 1168  Nepal                                       Mustard seed  2020
# 1169  Nepal                       Nutmeg, mace, cardamoms, raw  2020
# 1170  Nepal                                            Oranges  2020
# 1171  Nepal                                 Other beans, green  2020
# 1172  Nepal                         Other citrus fruit, n.e.c.  2020
# 1173  Nepal                               Other fruits, n.e.c.  2020
# 1174  Nepal                            Other oil seeds, n.e.c.  2020
# 1175  Nepal                                Other pulses n.e.c.  2020
# 1176  Nepal  Other stimulant, spice and aromatic crops, n.e.c.  2020
# 1177  Nepal                     Other vegetables, fresh n.e.c.  2020
# 1178  Nepal                                            Papayas  2020
# 1179  Nepal                             Peaches and nectarines  2020
# 1180  Nepal                                              Pears  2020
# 1181  Nepal                                         Persimmons  2020
# 1182  Nepal                                   Pigeon peas, dry  2020
# 1183  Nepal                                         Pineapples  2020
# 1184  Nepal                                    Plums and sloes  2020
# 1185  Nepal                                           Potatoes  2020
# 1186  Nepal                                               Rice  2020
# 1187  Nepal                              Seed cotton, unginned  2020
# 1188  Nepal                                         Soya beans  2020
# 1189  Nepal                                         Sugar cane  2020
# 1190  Nepal                 Tangerines, mandarins, clementines  2020
# 1191  Nepal                                         Tea leaves  2020
# 1192  Nepal                             Unmanufactured tobacco  2020
# 1193  Nepal                                  Walnuts, in shell  2020
# 1194  Nepal                                              Wheat  2020
#
#       hg/ha_yield  rainfall
# 1141         5675      1500
# 1142        81982      1500
# 1143        61661      1500
# 1144        33102      1500
# 1145       152201      1500
# 1146        12763      1500
# 1147         8611      1500
# 1148         8864      1500
# 1149        11307      1500
# 1150       267429      1500
# 1151       198068      1500
# 1152        11305      1500
# 1153        66198      1500
# 1154       100425      1500
# 1155       140000      1500
# 1156         1261      1500
# 1157        51754      1500
# 1158       127211      1500
# 1159        72517      1500
# 1160        13455      1500
# 1161        83531      1500
# 1162        12347      1500
# 1163        60747      1500
# 1164        10430      1500
# 1165        29611      1500
# 1166       106615      1500
# 1167        12225      1500
# 1168        10914      1500
# 1169         5762      1500
# 1170       115838      1500
# 1171        27344      1500
# 1172        66995      1500
# 1173       113807      1500
# 1174        10349      1500
# 1175        10582      1500
# 1176        69373      1500
# 1177       140944      1500
# 1178       132585      1500
# 1179        69221      1500
# 1180        99163      1500
# 1181        77066      1500
# 1182        10099      1500
# 1183       131125      1500
# 1184        65497      1500
# 1185       166500      1500
# 1186        38153      1500
# 1187         9558      1500
# 1188        12902      1500
# 1189       495905      1500
# 1190       107340      1500
# 1191        70765      1500
# 1192        11967      1500
# 1193        46021      1500
# 1194        30887      1500

# %% [markdown]
# # Pesticide Data

# %%
dataframe_pesticide = pd.read_csv("C:/Users/ASUS/crop/project/pesticide.csv")
dataframe_pesticide.head()
# Out:
#   Domain Code          Domain  Area Code (M49)   Area  Element Code  \
# 0          RP  Pesticides Use              524  Nepal          5157
# 1          RP  Pesticides Use              524  Nepal          5157
# 2          RP  Pesticides Use              524  Nepal          5157
# 3          RP  Pesticides Use              524  Nepal          5157
# 4          RP  Pesticides Use              524  Nepal          5157
#
#             Element  Item Code                Item  Year Code  Year Unit  \
# 0  Agricultural Use       1357  Pesticides (total)       1990  1990    t
# 1  Agricultural Use       1357  Pesticides (total)       1991  1991    t
# 2  Agricultural Use       1357  Pesticides (total)       1992  1992    t
# 3  Agricultural Use       1357  Pesticides (total)       1993  1993    t
# 4  Agricultural Use       1357  Pesticides (total)       1994  1994    t
#
#    Value Flag Flag Description  Note
# 0  60.11    E  Estimated value   NaN
# 1  60.11    E  Estimated value   NaN
# 2  60.11    E  Estimated value   NaN
# 3  60.11    E  Estimated value   NaN
# 4  60.11    E  Estimated value   NaN

# %%
#Renaming the column  
dataframe_pesticide = dataframe_pesticide.rename(index=str, columns={"Value": "pesticides_tonnes"})

# %%
dataframe_pesticide = dataframe_pesticide.drop(['Element','Domain', 'Domain Code', 'Area Code (M49)', 'Element Code', 'Item Code',  'Unit','Item', 'Year Code', 'Item Code', 'Flag', 'Flag Description', 'Note'], axis = 1)

# %%
dataframe_pesticide
# Out:
#      Area  Year  pesticides_tonnes
# 0   Nepal  1990              60.11
# 1   Nepal  1991              60.11
# 2   Nepal  1992              60.11
# 3   Nepal  1993              60.11
# 4   Nepal  1994              60.11
# 5   Nepal  1995              60.11
# 6   Nepal  1996              70.43
# 7   Nepal  1997              80.75
# 8   Nepal  1998              91.07
# 9   Nepal  1999             101.39
# 10  Nepal  2000             111.72
# 11  Nepal  2001             122.04
# 12  Nepal  2002             132.36
# 13  Nepal  2003             142.68
# 14  Nepal  2004             153.00
# 15  Nepal  2005             127.99
# 16  Nepal  2006             128.73
# 17  Nepal  2007             344.06
# 18  Nepal  2008             353.43
# 19  Nepal  2009             209.52
# 20  Nepal  2010             332.01
# 21  Nepal  2011             342.92
# 22  Nepal  2012             410.32
# 23  Nepal  2013             454.53
# 24  Nepal  2014             549.17
# 25  Nepal  2015             573.97
# 26  Nepal  2016             632.75
# 27  Nepal  2017             691.53
# 28  Nepal  2018             750.31
# 29  Nepal  2019             809.09
# 30  Nepal  2020             681.50
# 31  Nepal  2021             783.14

# %%
#merging  
dataframe_main = pd.merge(dataframe_main, dataframe_pesticide, on=['Year','Area'])  
dataframe_main
# Out:
#        Area                                Item  Year  hg/ha_yield  rainfall  \
# 0     Nepal                   Almonds, in shell  1998        10000      1500
# 1     Nepal                              Apples  1998       115078      1500
# 2     Nepal                            Apricots  1998        68548      1500
# 3     Nepal                          Areca nuts  1998        19375      1500
# 4     Nepal                             Bananas  1998       161980      1500
# ...     ...                                 ...   ...          ...       ...
# 1587  Nepal  Tangerines, mandarins, clementines  1997        70000      1500
# 1588  Nepal                          Tea leaves  1997        21850      1500
# 1589  Nepal              Unmanufactured tobacco  1997         7901      1500
# 1590  Nepal                   Walnuts, in shell  1997        38889      1500
# 1591  Nepal                               Wheat  1997        16072      1500
#
#       pesticides_tonnes
# 0                 91.07
# 1                 91.07
# 2                 91.07
# 3                 91.07
# 4                 91.07
# ...                 ...
# 1587              80.75
# 1588              80.75
# 1589              80.75
# 1590              80.75
# 1591              80.75
#
# [1592 rows x 6 columns]

# %%
filtered = dataframe_main[dataframe_main['Year'] == 2020]
filtered
# Out:
#        Area                                               Item  Year  \
# 1141  Nepal                                  Almonds, in shell  2020
# 1142  Nepal                                             Apples  2020
# 1143  Nepal                                           Apricots  2020
# 1144  Nepal                                         Areca nuts  2020
# 1145  Nepal                                            Bananas  2020
# 1146  Nepal                                             Barley  2020
# 1147  Nepal                                         Beans, dry  2020
# 1148  Nepal                   Broad beans and horse beans, dry  2020
# 1149  Nepal                                          Buckwheat  2020
# 1150  Nepal                                           Cabbages  2020
# 1151  Nepal                          Cauliflowers and broccoli  2020
# 1152  Nepal                                    Chick peas, dry  2020
# 1153  Nepal  Chillies and peppers, dry (Capsicum spp., Pime...  2020
# 1154  Nepal  Chillies and peppers, green (Capsicum spp. and...  2020
# 1155  Nepal                                 Coconuts, in shell  2020
# 1156  Nepal                                      Coffee, green  2020
# 1157  Nepal  Edible roots and tubers with high starch or in...  2020
# 1158  Nepal                                        Ginger, raw  2020
# 1159  Nepal                                       Green garlic  2020
# 1160  Nepal                                Jute, raw or retted  2020
# 1161  Nepal                                   Lemons and limes  2020
# 1162  Nepal                                       Lentils, dry  2020
# 1163  Nepal                                Lettuce and chicory  2020
# 1164  Nepal                                            Linseed  2020
# 1165  Nepal                                       Maize (corn)  2020
# 1166  Nepal                    Mangoes, guavas and mangosteens  2020
# 1167  Nepal                                             Millet  2020
# 1168  Nepal                                       Mustard seed  2020
# 1169  Nepal                       Nutmeg, mace, cardamoms, raw  2020
# 1170  Nepal                                            Oranges  2020
# 1171  Nepal                                 Other beans, green  2020
# 1172  Nepal                         Other citrus fruit, n.e.c.  2020
# 1173  Nepal                               Other fruits, n.e.c.  2020
# 1174  Nepal                            Other oil seeds, n.e.c.  2020
# 1175  Nepal                                Other pulses n.e.c.  2020
# 1176  Nepal  Other stimulant, spice and aromatic crops, n.e.c.  2020
# 1177  Nepal                     Other vegetables, fresh n.e.c.  2020
# 1178  Nepal                                            Papayas  2020
# 1179  Nepal                             Peaches and nectarines  2020
# 1180  Nepal                                              Pears  2020
# 1181  Nepal                                         Persimmons  2020
# 1182  Nepal                                   Pigeon peas, dry  2020
# 1183  Nepal                                         Pineapples  2020
# 1184  Nepal                                    Plums and sloes  2020
# 1185  Nepal                                           Potatoes  2020
# 1186  Nepal                                               Rice  2020
# 1187  Nepal                              Seed cotton, unginned  2020
# 1188  Nepal                                         Soya beans  2020
# 1189  Nepal                                         Sugar cane  2020
# 1190  Nepal                 Tangerines, mandarins, clementines  2020
# 1191  Nepal                                         Tea leaves  2020
# 1192  Nepal                             Unmanufactured tobacco  2020
# 1193  Nepal                                  Walnuts, in shell  2020
# 1194  Nepal                                              Wheat  2020
#
#       hg/ha_yield  rainfall  pesticides_tonnes
# 1141         5675      1500              681.5
# 1142        81982      1500              681.5
# 1143        61661      1500              681.5
# 1144        33102      1500              681.5
# 1145       152201      1500              681.5
# 1146        12763      1500              681.5
# 1147         8611      1500              681.5
# 1148         8864      1500              681.5
# 1149        11307      1500              681.5
# 1150       267429      1500              681.5
# 1151       198068      1500              681.5
# 1152        11305      1500              681.5
# 1153        66198      1500              681.5
# 1154       100425      1500              681.5
# 1155       140000      1500              681.5
# 1156         1261      1500              681.5
# 1157        51754      1500              681.5
# 1158       127211      1500              681.5
# 1159        72517      1500              681.5
# 1160        13455      1500              681.5
# 1161        83531      1500              681.5
# 1162        12347      1500              681.5
# 1163        60747      1500              681.5
# 1164        10430      1500              681.5
# 1165        29611      1500              681.5
# 1166       106615      1500              681.5
# 1167        12225      1500              681.5
# 1168        10914      1500              681.5
# 1169         5762      1500              681.5
# 1170       115838      1500              681.5
# 1171        27344      1500              681.5
# 1172        66995      1500              681.5
# 1173       113807      1500              681.5
# 1174        10349      1500              681.5
# 1175        10582      1500              681.5
# 1176        69373      1500              681.5
# 1177       140944      1500              681.5
# 1178       132585      1500              681.5
# 1179        69221      1500              681.5
# 1180        99163      1500              681.5
# 1181        77066      1500              681.5
# 1182        10099      1500              681.5
# 1183       131125      1500              681.5
# 1184        65497      1500              681.5
# 1185       166500      1500              681.5
# 1186        38153      1500              681.5
# 1187         9558      1500              681.5
# 1188        12902      1500              681.5
# 1189       495905      1500              681.5
# 1190       107340      1500              681.5
# 1191        70765      1500              681.5
# 1192        11967      1500              681.5
# 1193        46021      1500              681.5
# 1194        30887      1500              681.5

# %% [markdown]
# # Temperature Data

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv("C:/Users/ASUS/crop/project/temperature.csv")


dataframe_temp = df.iloc[89: , 0:3]
dataframe_temp
# Out:
#      Year  Annual Mean   Area
# 89   1990        13.67  Nepal
# 90   1991        13.55  Nepal
# 91   1992        13.34  Nepal
# 92   1993        13.77  Nepal
# 93   1994        13.86  Nepal
# 94   1995        13.94  Nepal
# 95   1996        13.97  Nepal
# 96   1997        13.10  Nepal
# 97   1998        14.23  Nepal
# 98   1999        14.47  Nepal
# 99   2000        13.99  Nepal
# 100  2001        14.31  Nepal
# 101  2002        14.28  Nepal
# 102  2003        14.20  Nepal
# 103  2004        14.40  Nepal
# 104  2005        14.26  Nepal
# 105  2006        14.70  Nepal
# 106  2007        14.59  Nepal
# 107  2008        14.19  Nepal
# 108  2009        14.91  Nepal
# 109  2010        14.94  Nepal
# 110  2011        14.21  Nepal
# 111  2012        14.10  Nepal
# 112  2013        13.98  Nepal
# 113  2014        14.06  Nepal
# 114  2015        14.08  Nepal
# 115  2016        14.77  Nepal
# 116  2017        14.53  Nepal
# 117  2018        14.26  Nepal
# 118  2019        14.08  Nepal
# 119  2020        13.89  Nepal
# 120  2021        14.29  Nepal
# 121  2022        14.39  Nepal

# %%
dataframe_temp = dataframe_temp.rename(index=str, columns={"Annual Mean": "avg_temp"})  
dataframe_temp.head()
# Out:
#     Year  avg_temp   Area
# 89  1990     13.67  Nepal
# 90  1991     13.55  Nepal
# 91  1992     13.34  Nepal
# 92  1993     13.77  Nepal
# 93  1994     13.86  Nepal

# %%
#merging the temperature dataframe with the main dataframe  
dataframe_main = pd.merge(dataframe_main,dataframe_temp, on=['Area','Year'])  
dataframe_main.head()
# Out:
#     Area               Item  Year  hg/ha_yield  rainfall  pesticides_tonnes  \
# 0  Nepal  Almonds, in shell  1998        10000      1500              91.07
# 1  Nepal             Apples  1998       115078      1500              91.07
# 2  Nepal           Apricots  1998        68548      1500              91.07
# 3  Nepal         Areca nuts  1998        19375      1500              91.07
# 4  Nepal            Bananas  1998       161980      1500              91.07
#
#    avg_temp
# 0     14.23
# 1     14.23
# 2     14.23
# 3     14.23
# 4     14.23

# %% [markdown]
# # MAIN DATAFRAME CREATED

# %%
dataframe_main.describe()
# Out:
#               Year    hg/ha_yield  rainfall  pesticides_tonnes     avg_temp
# count  1592.000000    1592.000000    1592.0        1592.000000  1592.000000
# mean   2006.258794   63675.468593    1500.0         315.303480    14.176394
# std       9.100576   74140.627872       0.0         254.029065     0.396938
# min    1990.000000    1250.000000    1500.0          60.110000    13.100000
# 25%    1999.000000    9868.750000    1500.0         101.390000    13.980000
# 50%    2007.000000   39833.500000    1500.0         209.520000    14.200000
# 75%    2014.000000   90097.000000    1500.0         549.170000    14.400000
# max    2021.000000  537094.000000    1500.0         809.090000    14.940000

# %%
dataframe_main.isnull().sum()
# Out:
# Area                 0
# Item                 0
# Year                 0
# hg/ha_yield          0
# rainfall             0
# pesticides_tonnes    0
# avg_temp             0
# dtype: int64

# %%
#Grouping on the basis of Item  
dataframe_main.groupby('Item').count()
# Out:
#                                                     Area  Year  hg/ha_yield  \
# Item
# Almonds, in shell                                     24    24           24
# Apples                                                32    32           32
# Apricots                                              32    32           32
# Areca nuts                                            32    32           32
# Bananas                                               32    32           32
# Barley                                                32    32           32
# Beans, dry                                            32    32           32
# Broad beans and horse beans, dry                      28    28           28
# Buckwheat                                             20    20           20
# Cabbages                                              23    23           23
# Cauliflowers and broccoli                             12    12           12
# Chick peas, dry                                       32    32           32
# Chillies and peppers, dry (Capsicum spp., Pimen...    32    32           32
# Chillies and peppers, green (Capsicum spp. and ...    24    24           24
# Coconuts, in shell                                    24    24           24
# Coffee, green                                         27    27           27
# Edible roots and tubers with high starch or inu...    32    32           32
# Ginger, raw                                           32    32           32
# Green garlic                                          24    24           24
# Jute, raw or retted                                   32    32           32
# Lemons and limes                                      32    32           32
# Lentils, dry                                          32    32           32
# Lettuce and chicory                                   19    19           19
# Linseed                                               32    32           32
# Maize (corn)                                          32    32           32
# Mangoes, guavas and mangosteens                       32    32           32
# Millet                                                32    32           32
# Mustard seed                                          32    32           32
# Nutmeg, mace, cardamoms, raw                          32    32           32
# Oranges                                               32    32           32
# Other beans, green                                    13    13           13
# Other citrus fruit, n.e.c.                            32    32           32
# Other fruits, n.e.c.                                  32    32           32
# Other oil seeds, n.e.c.                               10    10           10
# Other pulses n.e.c.                                   32    32           32
# Other stimulant, spice and aromatic crops, n.e.c.     32    32           32
# Other vegetables, fresh n.e.c.                        32    32           32
# Papayas                                               32    32           32
# Peaches and nectarines                                32    32           32
# Pears                                                 32    32           32
# Persimmons                                            32    32           32
# Pigeon peas, dry                                      32    32           32
# Pineapples                                            32    32           32
# Plums and sloes                                       32    32           32
# Potatoes                                              32    32           32
# Rice                                                  32    32           32
# Seed cotton, unginned                                 32    32           32
# Soya beans                                            32    32           32
# Sugar cane                                            32    32           32
# Tangerines, mandarins, clementines                    32    32           32
# Tea leaves                                            32    32           32
# Unmanufactured tobacco                                32    32           32
# Walnuts, in shell                                     32    32           32
# Wheat                                                 32    32           32
#
#                                                     rainfall  \
# Item
# Almonds, in shell                                         24
# Apples                                                    32
# Apricots                                                  32
# Areca nuts                                                32
# Bananas                                                   32
# Barley                                                    32
# Beans, dry                                                32
# Broad beans and horse beans, dry                          28
# Buckwheat                                                 20
# Cabbages                                                  23
# Cauliflowers and broccoli                                 12
# Chick peas, dry                                           32
# Chillies and peppers, dry (Capsicum spp., Pimen...        32
# Chillies and peppers, green (Capsicum spp. and ...        24
# Coconuts, in shell                                        24
# Coffee, green                                             27
# Edible roots and tubers with high starch or inu...        32
# Ginger, raw                                               32
# Green garlic                                              24
# Jute, raw or retted                                       32
# Lemons and limes                                          32
# Lentils, dry                                              32
# Lettuce and chicory                                       19
# Linseed                                                   32
# Maize (corn)                                              32
# Mangoes, guavas and mangosteens                           32
# Millet                                                    32
# Mustard seed                                              32
# Nutmeg, mace, cardamoms, raw                              32
# Oranges                                                   32
# Other beans, green                                        13
# Other citrus fruit, n.e.c.                                32
# Other fruits, n.e.c.                                      32
# Other oil seeds, n.e.c.                                   10
# Other pulses n.e.c.                                       32
# Other stimulant, spice and aromatic crops, n.e.c.         32
# Other vegetables, fresh n.e.c.                            32
# Papayas                                                   32
# Peaches and nectarines                                    32
# Pears                                                     32
# Persimmons                                                32
# Pigeon peas, dry                                          32
# Pineapples                                                32
# Plums and sloes                                           32
# Potatoes                                                  32
# Rice                                                      32
# Seed cotton, unginned                                     32
# Soya beans                                                32
# Sugar cane                                                32
# Tangerines, mandarins, clementines                        32
# Tea leaves                                                32
# Unmanufactured tobacco                                    32
# Walnuts, in shell                                         32
# Wheat                                                     32
#
#                                                     pesticides_tonnes  \
# Item
# Almonds, in shell                                                  24
# Apples                                                             32
# Apricots                                                           32
# Areca nuts                                                         32
# Bananas                                                            32
# Barley                                                             32
# Beans, dry                                                         32
# Broad beans and horse beans, dry                                   28
# Buckwheat                                                          20
# Cabbages                                                           23
# Cauliflowers and broccoli                                          12
# Chick peas, dry                                                    32
# Chillies and peppers, dry (Capsicum spp., Pimen...                 32
# Chillies and peppers, green (Capsicum spp. and ...                 24
# Coconuts, in shell                                                 24
# Coffee, green                                                      27
# Edible roots and tubers with high starch or inu...                 32
# Ginger, raw                                                        32
# Green garlic                                                       24
# Jute, raw or retted                                                32
# Lemons and limes                                                   32
# Lentils, dry                                                       32
# Lettuce and chicory                                                19
# Linseed                                                            32
# Maize (corn)                                                       32
# Mangoes, guavas and mangosteens                                    32
# Millet                                                             32
# Mustard seed                                                       32
# Nutmeg, mace, cardamoms, raw                                       32
# Oranges                                                            32
# Other beans, green                                                 13
# Other citrus fruit, n.e.c.                                         32
# Other fruits, n.e.c.                                               32
# Other oil seeds, n.e.c.                                            10
# Other pulses n.e.c.                                                32
# Other stimulant, spice and aromatic crops, n.e.c.                  32
# Other vegetables, fresh n.e.c.                                     32
# Papayas                                                            32
# Peaches and nectarines                                             32
# Pears                                                              32
# Persimmons                                                         32
# Pigeon peas, dry                                                   32
# Pineapples                                                         32
# Plums and sloes                                                    32
# Potatoes                                                           32
# Rice                                                               32
# Seed cotton, unginned                                              32
# Soya beans                                                         32
# Sugar cane                                                         32
# Tangerines, mandarins, clementines                                 32
# Tea leaves                                                         32
# Unmanufactured tobacco                                             32
# Walnuts, in shell                                                  32
# Wheat                                                              32
#
#                                                     avg_temp
# Item
# Almonds, in shell                                         24
# Apples                                                    32
# Apricots                                                  32
# Areca nuts                                                32
# Bananas                                                   32
# Barley                                                    32
# Beans, dry                                                32
# Broad beans and horse beans, dry                          28
# Buckwheat                                                 20
# Cabbages                                                  23
# Cauliflowers and broccoli                                 12
# Chick peas, dry                                           32
# Chillies and peppers, dry (Capsicum spp., Pimen...        32
# Chillies and peppers, green (Capsicum spp. and ...        24
# Coconuts, in shell                                        24
# Coffee, green                                             27
# Edible roots and tubers with high starch or inu...        32
# Ginger, raw                                               32
# Green garlic                                              24
# Jute, raw or retted                                       32
# Lemons and limes                                          32
# Lentils, dry                                              32
# Lettuce and chicory                                       19
# Linseed                                                   32
# Maize (corn)                                              32
# Mangoes, guavas and mangosteens                           32
# Millet                                                    32
# Mustard seed                                              32
# Nutmeg, mace, cardamoms, raw                              32
# Oranges                                                   32
# Other beans, green                                        13
# Other citrus fruit, n.e.c.                                32
# Other fruits, n.e.c.                                      32
# Other oil seeds, n.e.c.                                   10
# Other pulses n.e.c.                                       32
# Other stimulant, spice and aromatic crops, n.e.c.         32
# Other vegetables, fresh n.e.c.                            32
# Papayas                                                   32
# Peaches and nectarines                                    32
# Pears                                                     32
# Persimmons                                                32
# Pigeon peas, dry                                          32
# Pineapples                                                32
# Plums and sloes                                           32
# Potatoes                                                  32
# Rice                                                      32
# Seed cotton, unginned                                     32
# Soya beans                                                32
# Sugar cane                                                32
# Tangerines, mandarins, clementines                        32
# Tea leaves                                                32
# Unmanufactured tobacco                                    32
# Walnuts, in shell                                         32
# Wheat                                                     32

# %%
dataframe_main.describe()
# Out:
#               Year    hg/ha_yield  rainfall  pesticides_tonnes     avg_temp
# count  1592.000000    1592.000000    1592.0        1592.000000  1592.000000
# mean   2006.258794   63675.468593    1500.0         315.303480    14.176394
# std       9.100576   74140.627872       0.0         254.029065     0.396938
# min    1990.000000    1250.000000    1500.0          60.110000    13.100000
# 25%    1999.000000    9868.750000    1500.0         101.390000    13.980000
# 50%    2007.000000   39833.500000    1500.0         209.520000    14.200000
# 75%    2014.000000   90097.000000    1500.0         549.170000    14.400000
# max    2021.000000  537094.000000    1500.0         809.090000    14.940000

# %%
dataframe_main['Area'].nunique()
# Out:
# 1

# %%
dataframe_main.groupby(['Area'],sort=True)['hg/ha_yield'].sum().nlargest(10)
# Out:
# Area
# Nepal    101371346
# Name: hg/ha_yield, dtype: int64

# %%
dataframe_main.groupby(['Item','Area'],sort=True)['hg/ha_yield'].sum().nlargest(10)
# Out:
# Item                            Area
# Sugar cane                      Nepal    12997359
# Cabbages                        Nepal     5595879
# Bananas                         Nepal     5165253
# Pineapples                      Nepal     5098636
# Papayas                         Nepal     5058873
# Oranges                         Nepal     4167682
# Pears                           Nepal     3965240
# Potatoes                        Nepal     3780322
# Other vegetables, fresh n.e.c.  Nepal     3630206
# Ginger, raw                     Nepal     3526450
# Name: hg/ha_yield, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation matrix
correlation_data = dataframe_main.select_dtypes(include=[np.number]).corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(correlation_data, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation_data, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import OneHotEncoder  
  
dataframe_main_onehot = pd.get_dummies(dataframe_main, columns=['Area',"Item"], prefix = ['Country',"Item"])  
features=dataframe_main_onehot.loc[:, dataframe_main_onehot.columns != 'hg/ha_yield']  
label=dataframe_main['hg/ha_yield']  
features.head()
# Out:
#    Year  rainfall  pesticides_tonnes  avg_temp  Country_Nepal  \
# 0  1998      1500              91.07     14.23           True
# 1  1998      1500              91.07     14.23           True
# 2  1998      1500              91.07     14.23           True
# 3  1998      1500              91.07     14.23           True
# 4  1998      1500              91.07     14.23           True
#
#    Item_Almonds, in shell  Item_Apples  Item_Apricots  Item_Areca nuts  \
# 0                    True        False          False            False
# 1                   False         True          False            False
# 2                   False        False           True            False
# 3                   False        False          False             True
# 4                   False        False          False            False
#
#    Item_Bananas  ...  Item_Potatoes  Item_Rice  Item_Seed cotton, unginned  \
# 0         False  ...          False      False                       False
# 1         False  ...          False      False                       False
# 2         False  ...          False      False                       False
# 3         False  ...          False      False                       False
# 4          True  ...          False      False                       False
#
#    Item_Soya beans  Item_Sugar cane  Item_Tangerines, mandarins, clementines  \
# 0            False            False                                    False
# 1            False            False                                    False
# 2            False            False                                    False
# 3            False            False                                    False
# 4            False            False                                    False
#
#    Item_Tea leaves  Item_Unmanufactured tobacco  Item_Walnuts, in shell  \
# 0            False                        False                   False
# 1            False                        False                   False
# 2            False                        False                   False
# 3            False                        False                   False
# 4            False                        False                   False
#
#    Item_Wheat
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#
# [5 rows x 59 columns]

# %%
#Dropping the year column  
features= features.drop(['Year'], axis=1)  
  
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 58 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   rainfall                                                                        1592 non-null   int64
#  1   pesticides_tonnes                                                               1592 non-null   float64
#  2   avg_temp                                                                        1592 non-null   float64
#  3   Country_Nepal                                                                   1592 non-null   bool
#  4   Item_Almonds, in shell                                                          1592 non-null   bool
#  5   Item_Apples                                                                     1592 non-null   bool
#  6   Item_Apricots                                                                   1592 non-null   bool
#  7   Item_Areca nuts                                                                 1592 non-null   bool
#  8   Item_Bananas                                                                    1592 non-null   bool
#  9   Item_Barley                                                                     1592 non-null   bool
#  10  Item_Beans, dry                                                                 1592 non-null   bool
#  11  Item_Broad beans and horse beans, dry                                           1592 non-null   bool
#  12  Item_Buckwheat                                                                  1592 non-null   bool
#  13  Item_Cabbages                                                                   1592 non-null   bool
#  14  Item_Cauliflowers and broccoli                                                  1592 non-null   bool
#  15  Item_Chick peas, dry                                                            1592 non-null   bool
#  16  Item_Chillies and peppers, dry (Capsicum spp., Pimenta spp.), raw               1592 non-null   bool
#  17  Item_Chillies and peppers, green (Capsicum spp. and Pimenta spp.)               1592 non-null   bool
#  18  Item_Coconuts, in shell                                                         1592 non-null   bool
#  19  Item_Coffee, green                                                              1592 non-null   bool
#  20  Item_Edible roots and tubers with high starch or inulin content, n.e.c., fresh  1592 non-null   bool
#  21  Item_Ginger, raw                                                                1592 non-null   bool
#  22  Item_Green garlic                                                               1592 non-null   bool
#  23  Item_Jute, raw or retted                                                        1592 non-null   bool
#  24  Item_Lemons and limes                                                           1592 non-null   bool
#  25  Item_Lentils, dry                                                               1592 non-null   bool
#  26  Item_Lettuce and chicory                                                        1592 non-null   bool
#  27  Item_Linseed                                                                    1592 non-null   bool
#  28  Item_Maize (corn)                                                               1592 non-null   bool
#  29  Item_Mangoes, guavas and mangosteens                                            1592 non-null   bool
#  30  Item_Millet                                                                     1592 non-null   bool
#  31  Item_Mustard seed                                                               1592 non-null   bool
#  32  Item_Nutmeg, mace, cardamoms, raw                                               1592 non-null   bool
#  33  Item_Oranges                                                                    1592 non-null   bool
#  34  Item_Other beans, green                                                         1592 non-null   bool
#  35  Item_Other citrus fruit, n.e.c.                                                 1592 non-null   bool
#  36  Item_Other fruits, n.e.c.                                                       1592 non-null   bool
#  37  Item_Other oil seeds, n.e.c.                                                    1592 non-null   bool
#  38  Item_Other pulses n.e.c.                                                        1592 non-null   bool
#  39  Item_Other stimulant, spice and aromatic crops, n.e.c.                          1592 non-null   bool
#  40  Item_Other vegetables, fresh n.e.c.                                             1592 non-null   bool
#  41  Item_Papayas                                                                    1592 non-null   bool
#  42  Item_Peaches and nectarines                                                     1592 non-null   bool
#  43  Item_Pears                                                                      1592 non-null   bool
#  44  Item_Persimmons                                                                 1592 non-null   bool
#  45  Item_Pigeon peas, dry                                                           1592 non-null   bool
#  46  Item_Pineapples                                                                 1592 non-null   bool
#  47  Item_Plums and sloes                                                            1592 non-null   bool
#  48  Item_Potatoes                                                                   1592 non-null   bool
#  49  Item_Rice                                                                       1592 non-null   bool
#  50  Item_Seed cotton, unginned                                                      1592 non-null   bool
#  51  Item_Soya beans                                                                 1592 non-null   bool
#  52  Item_Sugar cane                                                                 1592 non-null   bool
#  53  Item_Tangerines, mandarins, clementines                                         1592 non-null   bool
#  54  Item_Tea leaves                                                                 1592 non-null   bool
#  55  Item_Unmanufactured tobacco                                                     1592 non-null   bool
#  56  Item_Walnuts, in shell                                                          1592 non-null   bool
#  57  Item_Wheat                                                                      1592 non-null   bool
# dtypes: bool(55), float64(2), int64(1)
# memory usage: 122.9 KB

# %%
from sklearn.preprocessing import MinMaxScaler  
scaler=MinMaxScaler()  
features=scaler.fit_transform(features)

# %%
features
# Out:
# array([[0.        , 0.04133622, 0.61413043, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.04133622, 0.61413043, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.04133622, 0.61413043, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.02755748, 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.        , 0.02755748, 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.        , 0.02755748, 0.        , ..., 0.        , 0.        ,
#         1.        ]])

# %%
from sklearn.model_selection import train_test_split  
train_data, test_data, train_labels, test_labels = train_test_split(features, label, test_size=0.2, random_state=42)

# %%
from sklearn.metrics import r2_score  
def compare_models(model):  
    model_name = model.__class__.__name__  
    fit=model.fit(train_data,train_labels)  
    y_pred=fit.predict(test_data)  
    r2=r2_score(test_labels,y_pred)  
    return([model_name,r2])  
  
from sklearn.ensemble import RandomForestRegressor  
from sklearn.ensemble import GradientBoostingRegressor  
from sklearn import svm  
from sklearn.tree import DecisionTreeRegressor  
  
models = [  
    GradientBoostingRegressor(n_estimators=200, max_depth=3, random_state=0),  
     RandomForestRegressor(n_estimators=200, max_depth=3, random_state=0),  
    svm.SVR(),  
   DecisionTreeRegressor()  
]  
  
model_train=list(map(compare_models,models))  
  
print(*model_train, sep = "\n")
# Out:
# ['GradientBoostingRegressor', 0.9371255795012301]
# ['RandomForestRegressor', 0.5539314758390168]
# ['SVR', -0.14606370491386178]
# ['DecisionTreeRegressor', 0.9323454429328981]

# %%
dataframe_main_onehotdataframe_main_onehot = dataframe_main_onehot.drop(['Year'], axis=1)  
dataframe_main_onehot.tail()
# Out:
#       Year  hg/ha_yield  rainfall  pesticides_tonnes  avg_temp  Country_Nepal  \
# 1587  1997        70000      1500              80.75      13.1           True
# 1588  1997        21850      1500              80.75      13.1           True
# 1589  1997         7901      1500              80.75      13.1           True
# 1590  1997        38889      1500              80.75      13.1           True
# 1591  1997        16072      1500              80.75      13.1           True
#
#       Item_Almonds, in shell  Item_Apples  Item_Apricots  Item_Areca nuts  \
# 1587                   False        False          False            False
# 1588                   False        False          False            False
# 1589                   False        False          False            False
# 1590                   False        False          False            False
# 1591                   False        False          False            False
#
#       ...  Item_Potatoes  Item_Rice  Item_Seed cotton, unginned  \
# 1587  ...          False      False                       False
# 1588  ...          False      False                       False
# 1589  ...          False      False                       False
# 1590  ...          False      False                       False
# 1591  ...          False      False                       False
#
#       Item_Soya beans  Item_Sugar cane  \
# 1587            False            False
# 1588            False            False
# 1589            False            False
# 1590            False            False
# 1591            False            False
#
#       Item_Tangerines, mandarins, clementines  Item_Tea leaves  \
# 1587                                     True            False
# 1588                                    False             True
# 1589                                    False            False
# 1590                                    False            False
# 1591                                    False            False
#
#       Item_Unmanufactured tobacco  Item_Walnuts, in shell  Item_Wheat
# 1587                        False                   False       False
# 1588                        False                   False       False
# 1589                         True                   False       False
# 1590                        False                    True       False
# 1591                        False                   False        True
#
# [5 rows x 60 columns]

# %%
import matplotlib.pyplot as plt

# Define a function to plot actual vs predicted values
def plot_actual_vs_predicted(model, model_name):
    fit = model.fit(train_data, train_labels)
    y_pred = fit.predict(test_data)
    plt.figure(figsize=(8, 6))
    plt.scatter(test_labels, y_pred, alpha=0.5)
    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.title(f"Actual vs Predicted ({model_name})")
    plt.show()

# Loop through models, fit them, predict, and plot actual vs predicted values
for model, model_name in zip(models, [model.__class__.__name__ for model in models]):
    plot_actual_vs_predicted(model, model_name)
